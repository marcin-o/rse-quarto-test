# %% [raw]
# ---
# author: "Marcin Oracz"
# date: "2026-04-27"
# title: "Template project"
# execute:
#     enabled: true
# ---

# %%
import numpy as np
x = np.arctan(1)*4

print(x)
# Out:
# 3.141592653589793

# %% [markdown]
# The value of $\pi$ is: `{python} f"{x:.4g}"`
